# %%
import pickle

# %%
filename = "artist_dic.pkl"

# %%
artist_dic = pickle.load(open(filename, 'rb'))

# %%
artist_dic["/dj/davidguetta"]["followers"]
# Out:
# {'url': '/dj/davidguetta',
#  'name': 'David Guetta',
#  'alias': [],
#  'country': 'France',
#  'followers': '25398'}

# %%
artist_dic["John Thomas"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-fd09274443f7> in <module>
# ----> 1 artist_dic["John Thomas"]
#
# KeyError: 'John Thomas'

# %%
L = []

for k,v in artist_dic.items():
    L.append((v["name"],int(v["followers"])))

# %%
L.sort(key = lambda a : -a[1])

# %%
L[::-1]
# Out:
# [('Julio Mejia', 0),
#  ('Adi Kolor', 0),
#  ('Laith', 0),
#  ('SCHAARUP', 0),
#  ('Aaron Azz', 0),
#  ('Nick Sly', 0),
#  ('Bendik Høibraaten', 0),
#  ('DJ Cloud', 0),
#  ('Rodin', 0),
#  ('Malfie', 0),
#  ('Jordss', 0),
#  ('Wantz', 0),
#  ('Gazzy Gaz', 0),
#  ('Bail', 0),
#  ('General.B', 0),
#  ('Sha Mi', 0),
#  ('Schmitzkatzki', 0),
#  ('Cázlo', 0),
#  ('Caner Seval', 0),
#  ('Quest of Fine', 0),
#  ('Daniela Mariposa', 0),
#  ('Eon Davis', 0),
#  ('Breezo', 0),
#  ('Ackers', 0),
#  ('Stauffenberg', 0),
#  ('Angelo Rojas', 0),
#  ('David Le Brun', 0),
#  ('David Monje', 0),
#  ('Carl OCallaghan', 0),
#  ('Nörb', 0),
#  ('August Lingheim', 0),
#  ('eden777', 0),
#  ('Ramon Rivé', 0),
#  ('Micallef', 0),
#  ('Riccardo Catria', 0),
#  ('Rumi von Baires', 0),
#  ('Alex Thomson', 0),
#  ('LIFN', 0),
#  ('Detroit Bureau of Sound', 0),
#  ('J-Buck', 0),
#  ('Eddy Gordo', 0),
#  ('Bandar Seri', 0),
#  ('CASIOp', 0),
#  ('Alessandro Nigro', 0),
#  ('John Palms', 0),
#  ('TIIMAL', 0),
# ...

# %%
list(artist_dic.keys())[:10]
# Out:
# ['/dj/davidguetta',
#  '/dj/tiesto',
#  '/dj/nickyromero',
#  '/dj/steveangello',
#  '/dj/robinschulz',
#  '/dj/arminvanbuuren',
#  '/dj/afrojack',
#  '/dj/carlcox',
#  '/dj/pvd',
#  '/dj/an21']

# %%
artist_dic["/dj/laurentgarnier"]
# Out:
# {'url': '/dj/laurentgarnier',
#  'name': 'Laurent Garnier',
#  'alias': ['Alaska, Choice'],
#  'country': 'France',
#  'followers': '25047'}

# %%
artists_names = pickle.load(open("artists_names.pkl", 'rb'))
